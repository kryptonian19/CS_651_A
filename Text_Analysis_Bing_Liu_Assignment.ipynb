# %% [markdown]
# # Importing the Dataset

# %%
#Importing the dataset
import pandas as pd 
df = pd.read_csv("C:/Users/seerl/Downloads/GooglePlayReviews.csv")
df.sample(10)

# This is a google play review dataset, we are only going to use the score column and the content column in this dataset
# Out:
#                                                 reviewId            userName  \
# 1197   gp:AOqpTOGRFxqU42LKn7c0evNoLJie_YeYLJ6uz_yDyHL...            Prashant
# 4961   gp:AOqpTOH6XKsH5Er_SuvhjFmQ8-PAbPYe86FR03fkqSV...        Glenn Weaver
# 2152   gp:AOqpTOG7NxumTInoSsnYkVnvkcDH-YgVu_IZJou5Pn9...        Angelica Law
# 6805   gp:AOqpTOHukI7EdSXQHnO2Ehxn-UL5sy5eg0VCxKq8K6P...      Avery Hilditch
# 1871   gp:AOqpTOF8E5N2_aN_xC3mYJOBZc01Egs5WR-93tsubxD...  Gianluca Rotzinger
# 12268  gp:AOqpTOFFBq3-d2fbJ3xZ0JqYTb3gKnoOyBFYljbBcbN...         Dania Shari
# 9563   gp:AOqpTOEerTvhvCO8ic-Aonota30u_gaqWiGBiTPlSua...         Amar Wakode
# 10527  gp:AOqpTOEecWYV0TGc5pl__iwA5WVJ2A_NZNFXxYjCG4u...              Esther
# 2600   gp:AOqpTOHzNtIIaK6DSQKiZS7TIXPF8ioVGUIZuIlDp2z...         vimal kumar
# 7203   gp:AOqpTOGz8yAdlyEcHFOQvts0bWAIR2b8umabR8viJtJ...       Shifaat Iqbal
#
#                                                userImage  \
# 1197   https://play-lh.googleusercontent.com/-eyIV_LH...
# ...

# %% [markdown]
# # Importing the opinion_lexicon package

# %%
from sklearn import preprocessing
import nltk
nltk.download('opinion_lexicon')
from nltk.corpus import opinion_lexicon
from nltk.tokenize import word_tokenize

print('Total number of words in opinion lexicon', len(opinion_lexicon.words()))
print('Examples of positive words in opinion lexicon',
      opinion_lexicon.positive()[:10])
print('Examples of negative words in opinion lexicon',
      opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon 6789
# Examples of positive words in opinion lexicon ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     C:\Users\seerl\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %% [markdown]
# # Creating Dictionary

# %%
# Let's create a dictionary which we can use for scoring our review text
nltk.download('punkt')
df.rename(columns={"reviewText": "text"}, inplace=True)
pos_score = 1
neg_score = -1
word_dict = {}
 
# Adding the positive words to the dictionary
for word in opinion_lexicon.positive():
        word_dict[word] = pos_score
      
# Adding the negative words to the dictionary
for word in opinion_lexicon.negative():
        word_dict[word] = neg_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\seerl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Bing Liu Function

# %%
# Calculating the bing_liu score by adding the scores in dictionary
def bing_liu_score(text):
    sentiment_score = 0
    bag_of_words = word_tokenize(text.lower())
    for word in bag_of_words:
        if word in word_dict:
            sentiment_score += word_dict[word]
    return sentiment_score

# %% [markdown]
# # Checking for empty spaces and applying bing liu function

# %%
# Checking for empty spaces and filling them with 'no review'
df['content'].fillna('no review', inplace=True)

# Apllying the bing_liu function
df['Bing_Liu_Score'] = df['content'].apply(bing_liu_score)

# %% [markdown]
# # Displaying the text with bing liu scores

# %%
df[['score',"content", 'Bing_Liu_Score']].head(10)
# Out:
#    score                                            content  Bing_Liu_Score
# 0      1                      I cannot open the app anymore               0
# 1      1  I have been begging for a refund from this app...               0
# 2      1  Very costly for the premium version (approx In...               1
# 3      1  Used to keep me organized, but all the 2020 UP...               0
# 4      1                                Dan Birthday Oct 28               0
# 5      1  It has changed how I viewed my different lists...               0
# 6      1  I'm only looking for a grocery list app but ev...               2
# 7      1  Reset my free trial, new phone I'd like to see...               3
# 8      1  How do to stop monthly payment because i don't...               0
# 9      1  I complain about not crashes and it was immedi...              -3

# %% [markdown]
# # Grouping the bing liu score by score column

# %%
# In this step, we will take the mean of all the bing liu scores for a particular score value, 
# and then group them as one value for that score
df.groupby('score').agg({'Bing_Liu_Score':'mean'})
# Out:
#        Bing_Liu_Score
# score
# 1           -0.071828
# 2            0.358788
# 3            0.871421
# 4            1.480000
# 5            1.700938
