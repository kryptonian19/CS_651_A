# %%
import pandas as pd
file = "C:/Users/seerl/Downloads/free-textobject-pair-descriptions-DFE.csv"
df = pd.read_csv(file)
df.head(20)
# Out:
#      _unit_id _unit_state  _trusted_judgments _last_judgment_at  \
# 0   693009422   finalized                   3     3/23/15 13:08
# 1   693009423   finalized                   3     3/23/15 14:38
# 2   693009424   finalized                   3      3/23/15 3:28
# 3   693009425   finalized                   3      3/23/15 3:26
# 4   693009426   finalized                   3      3/23/15 3:31
# 5   693009427   finalized                   3      3/23/15 3:30
# 6   693009428   finalized                   3      3/23/15 3:29
# 7   693009429   finalized                   3      3/23/15 3:22
# 8   693009430   finalized                   3      3/23/15 3:34
# 9   693009431   finalized                   3      3/23/15 3:34
# 10  693009432   finalized                   3      3/23/15 3:32
# 11  693009433   finalized                   3      3/23/15 3:30
# 12  693009434   finalized                   3      3/23/15 3:23
# 13  693009435   finalized                   3      3/23/15 3:22
# ...
